# %% [markdown]
# # Week 7 Lab: Data Visualization

# %% [markdown]
# Matplotlib colors: https://matplotlib.org/3.3.1/gallery/color/named_colors.html
#
# Dual y-axis plots: https://matplotlib.org/stable/gallery/subplots_axes_and_figures/two_scales.html

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Get Data

# %%
df = pd.read_csv('grouped_cases.csv')
df
# Out:
#           DATE  TOTAL CASES  BLACK CASES  HISPANIC CASES  WHITE CASES  \
# 0   2020-06-17    1127936.0     176855.0        301517.0     354711.0
# 1   2020-06-22    1282652.0     188968.0        331231.0     364858.0
# 2   2020-06-26    1372839.0     200971.0        356553.0     386845.0
# 3   2020-06-30    1509432.0     212814.0        385800.0     421089.0
# 4   2020-07-02    1560320.0     200771.0        358041.0     413511.0
# 5   2020-07-07    1737912.0     239292.0        429952.0     476503.0
# 6   2020-07-10    1858848.0     257120.0        459479.0     518107.0
# 7   2020-07-14    2015020.0     270464.0        486229.0     552077.0
# 8   2020-07-17    2146647.0     289376.0        515035.0     594098.0
# 9   2020-07-21    2324965.0     305062.0        552448.0     631447.0
# 10  2020-07-24    2448320.0     329137.0        578669.0     688203.0
# 11  2020-07-28    2643298.0     335384.0        590217.0     712492.0
# ...

# %% [markdown]
# #### How do total cases trend over time?

# %%
fig, ax = plt.subplots()
ax.plot(df['DATE'], df['TOTAL CASES'], color='mediumseagreen')

# Set axis labels
ax.set_xticks(ax.get_xticks()[::2])
ax.set_xticklabels(df['DATE'][::2], rotation = 45)

# Set title
ax.set_title('Total COVID-19 Cases')
ax.title.set_weight('bold')
ax.title.set_size(14)
ax.title.set_position([.5, 1.08])

# Set spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_lw(1.5)
ax.spines['left'].set_lw(1.5)

# Set font
plt.rcParams["font.family"] = "serif"

fig.show()
# Out:
# <ipython-input-20-86b97476b46a>:23: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# #### Compare total cases and cumulative incidence

# %%
def plot_aesthetics(ax, plt, title, xtick_labels, xtick_rotation):
    # add title
    ax.set_title(title)
    ax.title.set_weight('bold')
    ax.title.set_size(14)
    ax.title.set_position([.5, 1.08])
    
    # set xticks
    ax.set_xticks(ax.get_xticks()[::2])
    ax.set_xticklabels(xtick_labels[::2], rotation = xtick_rotation)
    
    # set spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_lw(1.5)
    ax.spines['left'].set_lw(1.5)
    
    # set font
    plt.rcParams["font.family"] = "serif"

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
ax2 = ax1.twinx()

ax1.plot(df['DATE'], df['TOTAL CASES'], color='goldenrod', label='Total Cases')
ax2.plot(df['DATE'], df['BLACK CI'], color='firebrick', label='Cumulative Incidence (Black)')
ax2.plot(df['DATE'], df['HISPANIC CI'], color='mediumseagreen', label='Cumulative Incidence (Hispanic)')
ax2.plot(df['DATE'], df['WHITE CI'], color='royalblue', label='Cumulative Incidence (White)')

# set title and axis labels
ax1.set_title('Total Cases vs. Cumulative Incidence by Race')
ax1.title.set_weight('bold')
ax1.title.set_size(14)
ax1.title.set_position([.5, 1.08])
ax1.set_ylabel('Total Cases', labelpad=10)
ax2.set_ylabel('Cumulative Incidence', labelpad=15)

# set xticks
ax1.set_xticks(ax1.get_xticks()[::2])
ax1.set_xticklabels(df['DATE'][::2], rotation = 45)
    
# set spines
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.spines['bottom'].set_lw(1.5)
ax1.spines['left'].set_lw(1.5)
    
# set font
plt.rcParams["font.family"] = "serif"

# set legend
fig.legend(loc='upper left')

fig.show()
# Out:
# <ipython-input-57-85080e5c32bb>:33: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# #### How do trends in cumulative incidence vary by race?

# %%
fig, ax = plt.subplots(3, 1)
ax[0].plot(df['DATE'], df['BLACK CI'], color='mediumseagreen')
ax[1].plot(df['DATE'], df['HISPANIC CI'], color='firebrick')
ax[2].plot(df['DATE'], df['WHITE CI'], color='royalblue')
plot_aesthetics(ax[0], 'Cumulative Incidence by Race', df['DATE'], 45)
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  <AxesSubplot:title={'center':'Cumulative Incidence by Race'}>)

# %%
y_list = ['BLACK CI', 'HISPANIC CI', 'WHITE CI']
colors = ['mediumseagreen', 'firebrick', 'royalblue']
fig, ax = plt.subplots(3, 1)
for i in range(len(y_list)):
    ax[i].plot(df['DATE'], df[y_list[i]], color=colors[i])
fig.show()
# Out:
# <ipython-input-31-814a73d19b38>:6: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
