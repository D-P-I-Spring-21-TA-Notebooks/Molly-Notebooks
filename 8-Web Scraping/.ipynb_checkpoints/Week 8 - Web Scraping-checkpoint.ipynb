# %% [markdown]
# # Week 8 - Web Scraping

# %% [markdown]
# ### Objective:
#
# #### Parse data from the HTML of a website

# %% [markdown]
# ### Helpful Resources
#
# Site to scrape - https://www.multistate.us/issues/covid-19-state-reopening-guide
#
# Beautiful Soup documentation - https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# #### Import libraries

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# #### Make soup

# %% [markdown]
# Make request to website

# %%
response_ranks = requests.get('https://www.multistate.us/issues/covid-19-state-reopening-guide')
type(response_ranks)
# Out:
# requests.models.Response

# %% [markdown]
# Create soup object from response object

# %%
soup_ranks = BeautifulSoup(response_ranks.text, 'lxml')
type(soup_ranks)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# #### Check soup

# %%
soup_ranks.title
# Out:
# <title>COVID-19 State Reopening Guide | MultiState</title>

# %%
'COVID' in soup_ranks.text
# Out:
# True

# %%
'Ratings' in soup_ranks.text
# Out:
# True

# %%
'Molly' in soup_ranks.text
# Out:
# False

# %% [markdown]
# #### Soup to array

# %% [markdown]
# Retrieve the ratings table from the soup object

# %%
rank_rable = soup_ranks.find('table') # this works because our soup has only one table

# %% [markdown]
# Retrieve the values in the table, and create an array

# %%
array_ranks = []
for row in table.find_all('tr'): # tr = table row
    temp = [] # create empty array for each table row
    for cell in row.find_all(['th', 'td']): # th = table header; td = table cell
        temp.append(cell.text)
    array_ranks.append(temp)
array_ranks
# Out:
# [['Rank', 'State', 'Score', 'Rank', 'State', 'Score'],
#  ['(1)', 'Alabama', '100', '(26)', 'North Carolina', '90'],
#  ['(2)', 'Arizona', '100', '(27)', 'Utah', '90'],
#  ['(3)', 'Arkansas', '100', '(28)', 'Wisconsin', '90'],
#  ['(4)', 'Florida', '100', '(29)', 'Connecticut', '86'],
#  ['(5)', 'Georgia', '100', '(30)', 'Ohio', '86'],
#  ['(6)', 'South Carolina', '100', '(31)', 'New Jersey', '82'],
#  ['(7)', 'Alaska', '96', '(32)', 'Virginia', '81'],
#  ['(8)', 'Indiana', '96', '(33)', 'Vermont', '80'],
#  ['(9)', 'Iowa', '96', '(34)', 'New York', '79'],
#  ['(10)', 'Montana', '96', '(35)', 'Minnesota', '74'],
#  ['(11)', 'New Hampshire', '96', '(36)', 'Maine', '72'],
#  ['(12)', 'North Dakota', '96', '(37)', 'Nevada', '72'],
#  ['(13)', 'Oklahoma', '96', '(38)', 'Kentucky', '70'],
#  ['(14)', 'South Dakota', '96', '(39)', 'Pennsylvania', '68'],
#  ['(15)', 'Texas', '96', '(40)', 'Michigan', '65'],
#  ['(16)', 'West Virginia', '96', '(41)', 'Rhode Island', '63'],
#  ['(17)', 'Louisiana', '93', '(42)', 'Massachusetts', '61'],
#  ['(18)', 'Nebraska', '93', '(43)', 'Colorado', '60'],
#  ['(19)', 'Tennessee', '93', '(44)', 'New Mexico', '60'],
#  ['(20)', 'Wyoming', '92', '(45)', 'Illinois', '54'],
#  ['(21)', 'Idaho', '90', '(46)', 'California', '53'],
#  ['(22)', 'Kansas', '90', '(47)', 'Washington', '52'],
#  ['(23)', 'Maryland', '90', '(48)', 'Delaware', '51'],
#  ['(24)', 'Mississippi', '90', '(49)', 'Oregon', '49'],
#  ['(25)', 'Missouri', '90', '(50)', 'Hawaii', '48']]

# %% [markdown]
# #### Array to dataframe

# %% [markdown]
# Using the array from above, create a pandas dataframe

# %%
colnames = array_ranks[0] # first array in our nested array contains the column names
df_ranks = pd.DataFrame(data=array_ranks, columns=colnames)
df_ranks
# Out:
#     Rank           State  Score  Rank           State  Score
# 0   Rank           State  Score  Rank           State  Score
# 1    (1)         Alabama    100  (26)  North Carolina     90
# 2    (2)         Arizona    100  (27)            Utah     90
# 3    (3)        Arkansas    100  (28)       Wisconsin     90
# 4    (4)         Florida    100  (29)     Connecticut     86
# 5    (5)         Georgia    100  (30)            Ohio     86
# 6    (6)  South Carolina    100  (31)      New Jersey     82
# 7    (7)          Alaska     96  (32)        Virginia     81
# 8    (8)         Indiana     96  (33)         Vermont     80
# 9    (9)            Iowa     96  (34)        New York     79
# 10  (10)         Montana     96  (35)       Minnesota     74
# 11  (11)   New Hampshire     96  (36)           Maine     72
# 12  (12)    North Dakota     96  (37)          Nevada     72
# 13  (13)        Oklahoma     96  (38)        Kentucky     70
# 14  (14)    South Dakota     96  (39)    Pennsylvania     68
# 15  (15)           Texas     96  (40)        Michigan     65
# 16  (16)   West Virginia     96  (41)    Rhode Island     63
# 17  (17)       Louisiana     93  (42)   Massachusetts     61
# 18  (18)        Nebraska     93  (43)        Colorado     60
# 19  (19)       Tennessee     93  (44)      New Mexico     60
# 20  (20)         Wyoming     92  (45)        Illinois     54
# 21  (21)           Idaho     90  (46)      California     53
# 22  (22)          Kansas     90  (47)      Washington     52
# 23  (23)        Maryland     90  (48)        Delaware     51
# 24  (24)     Mississippi     90  (49)          Oregon     49
# 25  (25)        Missouri     90  (50)          Hawaii     48

# %%
df_ranks.drop([0], inplace=True)
df_ranks
# Out:
#     Rank           State Score  Rank           State Score
# 1    (1)         Alabama   100  (26)  North Carolina    90
# 2    (2)         Arizona   100  (27)            Utah    90
# 3    (3)        Arkansas   100  (28)       Wisconsin    90
# 4    (4)         Florida   100  (29)     Connecticut    86
# 5    (5)         Georgia   100  (30)            Ohio    86
# 6    (6)  South Carolina   100  (31)      New Jersey    82
# 7    (7)          Alaska    96  (32)        Virginia    81
# 8    (8)         Indiana    96  (33)         Vermont    80
# 9    (9)            Iowa    96  (34)        New York    79
# 10  (10)         Montana    96  (35)       Minnesota    74
# 11  (11)   New Hampshire    96  (36)           Maine    72
# 12  (12)    North Dakota    96  (37)          Nevada    72
# 13  (13)        Oklahoma    96  (38)        Kentucky    70
# 14  (14)    South Dakota    96  (39)    Pennsylvania    68
# 15  (15)           Texas    96  (40)        Michigan    65
# 16  (16)   West Virginia    96  (41)    Rhode Island    63
# 17  (17)       Louisiana    93  (42)   Massachusetts    61
# 18  (18)        Nebraska    93  (43)        Colorado    60
# 19  (19)       Tennessee    93  (44)      New Mexico    60
# 20  (20)         Wyoming    92  (45)        Illinois    54
# 21  (21)           Idaho    90  (46)      California    53
# 22  (22)          Kansas    90  (47)      Washington    52
# 23  (23)        Maryland    90  (48)        Delaware    51
# 24  (24)     Mississippi    90  (49)          Oregon    49
# 25  (25)        Missouri    90  (50)          Hawaii    48

# %% [markdown]
# Fix repeated columns

# %%
df1 = df_ranks.iloc[:, 0:3]
df2 = df_ranks.iloc[:, 3:]
df_final = pd.concat([df1, df2]).reset_index()
df_final.drop(columns='index', inplace=True)
df_final
# Out:
#     Rank           State Score
# 0    (1)         Alabama   100
# 1    (2)         Arizona   100
# 2    (3)        Arkansas   100
# 3    (4)         Florida   100
# 4    (5)         Georgia   100
# 5    (6)  South Carolina   100
# 6    (7)          Alaska    96
# 7    (8)         Indiana    96
# 8    (9)            Iowa    96
# 9   (10)         Montana    96
# 10  (11)   New Hampshire    96
# 11  (12)    North Dakota    96
# 12  (13)        Oklahoma    96
# 13  (14)    South Dakota    96
# 14  (15)           Texas    96
# 15  (16)   West Virginia    96
# 16  (17)       Louisiana    93
# 17  (18)        Nebraska    93
# 18  (19)       Tennessee    93
# 19  (20)         Wyoming    92
# 20  (21)           Idaho    90
# 21  (22)          Kansas    90
# 22  (23)        Maryland    90
# 23  (24)     Mississippi    90
# 24  (25)        Missouri    90
# 25  (26)  North Carolina    90
# 26  (27)            Utah    90
# 27  (28)       Wisconsin    90
# 28  (29)     Connecticut    86
# 29  (30)            Ohio    86
# 30  (31)      New Jersey    82
# 31  (32)        Virginia    81
# 32  (33)         Vermont    80
# 33  (34)        New York    79
# 34  (35)       Minnesota    74
# 35  (36)           Maine    72
# 36  (37)          Nevada    72
# 37  (38)        Kentucky    70
# 38  (39)    Pennsylvania    68
# 39  (40)        Michigan    65
# 40  (41)    Rhode Island    63
# 41  (42)   Massachusetts    61
# 42  (43)        Colorado    60
# 43  (44)      New Mexico    60
# 44  (45)        Illinois    54
# 45  (46)      California    53
# 46  (47)      Washington    52
# 47  (48)        Delaware    51
# 48  (49)          Oregon    49
# 49  (50)          Hawaii    48
